# %%
# import dependencies
import numpy 
import sys
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

# %%
# loading dataset
file = open("Frankenstein-dataset.txt",encoding="utf8").read()

# %%
# tokenization
# standardization 
def tokenize_words(input):
    input = input.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens =  tokenizer.tokenize(input)
    filtered = filter(lambda token: token not in stopwords.words('english'),tokens)
    return "".join(filtered)

processed_inputs = tokenize_words(file)

# %%
# chars to numbers
chars = sorted(list(set(processed_inputs)))
char_to_num = dict((c,i) for i,c in enumerate(chars))

# %%
# check if words to chars or chars to num (?!) has worked?
input_len = len(processed_inputs)
vocab_len = len(chars)
print ("Total number of characters:", input_len)
print ("Total vocab:", vocab_len)
# Out:
# Total number of characters: 7038
# Total vocab: 27

# %%
#seq length
seq_length = 100
x_data = []
y_data = []

# %%
# loop through the sequence
for i in range(0, input_len - seq_length, 1):
    in_seq = processed_inputs[i:i + seq_length]
    out_seq = processed_inputs[i + seq_length]
    x_data.append([char_to_num[char] for char in in_seq])
    y_data.append(char_to_num[out_seq])
n_patterns = len(x_data)
print ("Total Patterns:", n_patterns)
# Out:
# Total Patterns: 13876

# %%
# convert input sequence to np array and so on
X = numpy.reshape(x_data, (n_patterns, seq_length, 1))
X = X/float(vocab_len)

# %%
# one-hot encoding
y = np_utils.to_categorical(y_data)

# %%
# creating the model
model = Sequential()
model.add(LSTM(256, input_shape = (X.shape[1], X.shape[2]), return_sequences= True))
model.add(Dropout(0.2))
model.add(LSTM(256, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation = 'softmax'))

# %%
# compile the model
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam')

# %%
#saving weights
filepath = "model_weights_saved.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor ='loss', verbose = 1, save_best_only = True, mode = 'min')
desired_callbacks = [checkpoint]

# %%
#fit model and let it train
model.fit(X,y, epochs = 100, batch_size = 256, callbacks= desired_callbacks)
# Out:
# Epoch 1/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8995
# Epoch 00001: loss did not improve from 2.89670
# 55/55 [==============================] - 276s 5s/step - loss: 2.8995
# Epoch 2/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8946
# Epoch 00002: loss improved from 2.89670 to 2.89455, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 301s 5s/step - loss: 2.8946
# Epoch 3/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8909
# Epoch 00003: loss improved from 2.89455 to 2.89086, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 331s 6s/step - loss: 2.8909
# Epoch 4/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8901
# Epoch 00004: loss improved from 2.89086 to 2.89014, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 326s 6s/step - loss: 2.8901
# Epoch 5/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8893
# Epoch 00005: loss improved from 2.89014 to 2.88931, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 306s 6s/step - loss: 2.8893
# Epoch 6/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8875
# Epoch 00006: loss improved from 2.88931 to 2.88753, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 322s 6s/step - loss: 2.8875
# Epoch 7/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8869
# Epoch 00007: loss improved from 2.88753 to 2.88691, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 320s 6s/step - loss: 2.8869
# Epoch 8/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8837
# Epoch 00008: loss improved from 2.88691 to 2.88369, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 365s 7s/step - loss: 2.8837
# Epoch 9/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8873
# Epoch 00009: loss did not improve from 2.88369
# 55/55 [==============================] - 342s 6s/step - loss: 2.8873
# Epoch 10/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8854
# Epoch 00010: loss did not improve from 2.88369
# 55/55 [==============================] - 339s 6s/step - loss: 2.8854
# Epoch 11/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8741
# Epoch 00011: loss improved from 2.88369 to 2.87410, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 378s 7s/step - loss: 2.8741
# Epoch 12/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8657
# Epoch 00012: loss improved from 2.87410 to 2.86567, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 404s 7s/step - loss: 2.8657
# Epoch 13/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8620
# Epoch 00013: loss improved from 2.86567 to 2.86197, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 416s 8s/step - loss: 2.8620
# Epoch 14/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8542
# Epoch 00014: loss improved from 2.86197 to 2.85417, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 391s 7s/step - loss: 2.8542
# Epoch 15/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8467
# Epoch 00015: loss improved from 2.85417 to 2.84670, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 395s 7s/step - loss: 2.8467
# Epoch 16/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8388
# Epoch 00016: loss improved from 2.84670 to 2.83884, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 397s 7s/step - loss: 2.8388
# Epoch 17/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8308
# Epoch 00017: loss improved from 2.83884 to 2.83079, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 419s 8s/step - loss: 2.8308
# Epoch 18/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8214
# Epoch 00018: loss improved from 2.83079 to 2.82137, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 391s 7s/step - loss: 2.8214
# Epoch 19/100
# 55/55 [==============================] - ETA: 0s - loss: 2.8120
# Epoch 00019: loss improved from 2.82137 to 2.81197, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 372s 7s/step - loss: 2.8120
# Epoch 20/100
# 55/55 [==============================] - ETA: 0s - loss: 2.7957
# Epoch 00020: loss improved from 2.81197 to 2.79566, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 371s 7s/step - loss: 2.7957
# Epoch 21/100
# 55/55 [==============================] - ETA: 0s - loss: 2.7798
# Epoch 00021: loss improved from 2.79566 to 2.77984, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 374s 7s/step - loss: 2.7798
# Epoch 22/100
# 55/55 [==============================] - ETA: 0s - loss: 2.7577
# Epoch 00022: loss improved from 2.77984 to 2.75773, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 385s 7s/step - loss: 2.7577
# Epoch 23/100
# 55/55 [==============================] - ETA: 0s - loss: 2.7237
# Epoch 00023: loss improved from 2.75773 to 2.72374, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 397s 7s/step - loss: 2.7237
# Epoch 24/100
# 55/55 [==============================] - ETA: 0s - loss: 2.6943
# Epoch 00024: loss improved from 2.72374 to 2.69430, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 376s 7s/step - loss: 2.6943
# Epoch 25/100
# 55/55 [==============================] - ETA: 0s - loss: 2.6528
# Epoch 00025: loss improved from 2.69430 to 2.65278, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 386s 7s/step - loss: 2.6528
# Epoch 26/100
# 55/55 [==============================] - ETA: 0s - loss: 2.5916
# Epoch 00026: loss improved from 2.65278 to 2.59155, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 406s 7s/step - loss: 2.5916
# Epoch 27/100
# 55/55 [==============================] - ETA: 0s - loss: 2.5276
# Epoch 00027: loss improved from 2.59155 to 2.52755, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 389s 7s/step - loss: 2.5276
# Epoch 28/100
# 55/55 [==============================] - ETA: 0s - loss: 2.4395
# Epoch 00028: loss improved from 2.52755 to 2.43948, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 370s 7s/step - loss: 2.4395
# Epoch 29/100
# 55/55 [==============================] - ETA: 0s - loss: 2.3527
# Epoch 00029: loss improved from 2.43948 to 2.35268, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 2.3527
# Epoch 30/100
# 55/55 [==============================] - ETA: 0s - loss: 2.2455
# Epoch 00030: loss improved from 2.35268 to 2.24546, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 352s 6s/step - loss: 2.2455
# Epoch 31/100
# 55/55 [==============================] - ETA: 0s - loss: 2.1343
# Epoch 00031: loss improved from 2.24546 to 2.13433, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 333s 6s/step - loss: 2.1343
# Epoch 32/100
# 55/55 [==============================] - ETA: 0s - loss: 2.0284
# Epoch 00032: loss improved from 2.13433 to 2.02839, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 296s 5s/step - loss: 2.0284
# Epoch 33/100
# 55/55 [==============================] - ETA: 0s - loss: 1.9216
# Epoch 00033: loss improved from 2.02839 to 1.92165, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 300s 5s/step - loss: 1.9216
# Epoch 34/100
# 55/55 [==============================] - ETA: 0s - loss: 1.7936
# Epoch 00034: loss improved from 1.92165 to 1.79364, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 294s 5s/step - loss: 1.7936
# Epoch 35/100
# 55/55 [==============================] - ETA: 0s - loss: 1.6768
# Epoch 00035: loss improved from 1.79364 to 1.67676, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 301s 5s/step - loss: 1.6768
# Epoch 36/100
# 55/55 [==============================] - ETA: 0s - loss: 1.5702
# Epoch 00036: loss improved from 1.67676 to 1.57025, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 292s 5s/step - loss: 1.5702
# Epoch 37/100
# 55/55 [==============================] - ETA: 0s - loss: 1.4799
# Epoch 00037: loss improved from 1.57025 to 1.47994, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 787s 14s/step - loss: 1.4799
# Epoch 38/100
# 55/55 [==============================] - ETA: 0s - loss: 1.3757
# Epoch 00038: loss improved from 1.47994 to 1.37566, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 298s 5s/step - loss: 1.3757
# Epoch 39/100
# 55/55 [==============================] - ETA: 0s - loss: 1.2488
# Epoch 00039: loss improved from 1.37566 to 1.24877, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 294s 5s/step - loss: 1.2488
# Epoch 40/100
# 55/55 [==============================] - ETA: 0s - loss: 1.1615
# Epoch 00040: loss improved from 1.24877 to 1.16154, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 313s 6s/step - loss: 1.1615
# Epoch 41/100
# 55/55 [==============================] - ETA: 0s - loss: 1.0784
# Epoch 00041: loss improved from 1.16154 to 1.07844, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 297s 5s/step - loss: 1.0784
# Epoch 42/100
# 55/55 [==============================] - ETA: 0s - loss: 0.9899
# Epoch 00042: loss improved from 1.07844 to 0.98986, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 372s 7s/step - loss: 0.9899
# Epoch 43/100
# 55/55 [==============================] - ETA: 0s - loss: 0.9178
# Epoch 00043: loss improved from 0.98986 to 0.91780, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 0.9178
# Epoch 44/100
# 55/55 [==============================] - ETA: 0s - loss: 0.8490
# Epoch 00044: loss improved from 0.91780 to 0.84899, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 367s 7s/step - loss: 0.8490
# Epoch 45/100
# 55/55 [==============================] - ETA: 0s - loss: 0.7817
# Epoch 00045: loss improved from 0.84899 to 0.78165, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 0.7817
# Epoch 46/100
# 55/55 [==============================] - ETA: 0s - loss: 0.7325
# Epoch 00046: loss improved from 0.78165 to 0.73255, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 367s 7s/step - loss: 0.7325
# Epoch 47/100
# 55/55 [==============================] - ETA: 0s - loss: 0.6659
# Epoch 00047: loss improved from 0.73255 to 0.66594, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 0.6659
# Epoch 48/100
# 55/55 [==============================] - ETA: 0s - loss: 0.6181
# Epoch 00048: loss improved from 0.66594 to 0.61809, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 0.6181
# Epoch 49/100
# 55/55 [==============================] - ETA: 0s - loss: 0.5714
# Epoch 00049: loss improved from 0.61809 to 0.57143, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 397s 7s/step - loss: 0.5714
# Epoch 50/100
# 55/55 [==============================] - ETA: 0s - loss: 0.5330
# Epoch 00050: loss improved from 0.57143 to 0.53301, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 384s 7s/step - loss: 0.5330
# Epoch 51/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4910
# Epoch 00051: loss improved from 0.53301 to 0.49097, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 387s 7s/step - loss: 0.4910
# Epoch 52/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4623
# Epoch 00052: loss improved from 0.49097 to 0.46228, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 370s 7s/step - loss: 0.4623
# Epoch 53/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4247
# Epoch 00053: loss improved from 0.46228 to 0.42473, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 377s 7s/step - loss: 0.4247
# Epoch 54/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3980
# Epoch 00054: loss improved from 0.42473 to 0.39801, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 367s 7s/step - loss: 0.3980
# Epoch 55/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3745
# Epoch 00055: loss improved from 0.39801 to 0.37453, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 367s 7s/step - loss: 0.3745
# Epoch 56/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3469
# Epoch 00056: loss improved from 0.37453 to 0.34694, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 367s 7s/step - loss: 0.3469
# Epoch 57/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3380
# Epoch 00057: loss improved from 0.34694 to 0.33796, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 0.3380
# Epoch 58/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3071
# Epoch 00058: loss improved from 0.33796 to 0.30706, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 346s 6s/step - loss: 0.3071
# Epoch 59/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2955
# Epoch 00059: loss improved from 0.30706 to 0.29548, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 293s 5s/step - loss: 0.2955
# Epoch 60/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2738
# Epoch 00060: loss improved from 0.29548 to 0.27380, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 294s 5s/step - loss: 0.2738
# Epoch 61/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2535
# Epoch 00061: loss improved from 0.27380 to 0.25353, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 415s 8s/step - loss: 0.2535
# Epoch 62/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2544
# Epoch 00062: loss did not improve from 0.25353
# 55/55 [==============================] - 301s 5s/step - loss: 0.2544
# Epoch 63/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2368
# Epoch 00063: loss improved from 0.25353 to 0.23677, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 295s 5s/step - loss: 0.2368
# Epoch 64/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2131
# Epoch 00064: loss improved from 0.23677 to 0.21309, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 294s 5s/step - loss: 0.2131
# Epoch 65/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2117
# Epoch 00065: loss improved from 0.21309 to 0.21168, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 294s 5s/step - loss: 0.2117
# Epoch 66/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2032
# Epoch 00066: loss improved from 0.21168 to 0.20316, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 1268s 23s/step - loss: 0.2032
# Epoch 67/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1884
# Epoch 00067: loss improved from 0.20316 to 0.18835, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 304s 6s/step - loss: 0.1884
# Epoch 68/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1858
# Epoch 00068: loss improved from 0.18835 to 0.18579, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 295s 5s/step - loss: 0.1858
# Epoch 69/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1657
# Epoch 00069: loss improved from 0.18579 to 0.16569, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 301s 5s/step - loss: 0.1657
# Epoch 70/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1602
# Epoch 00070: loss improved from 0.16569 to 0.16020, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 299s 5s/step - loss: 0.1602
# Epoch 71/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1584
# Epoch 00071: loss improved from 0.16020 to 0.15837, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 298s 5s/step - loss: 0.1584
# Epoch 72/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1543  - ETA: 3:04 -
# Epoch 00072: loss improved from 0.15837 to 0.15427, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 927s 17s/step - loss: 0.1543
# Epoch 73/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1532
# Epoch 00073: loss improved from 0.15427 to 0.15316, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 296s 5s/step - loss: 0.1532
# Epoch 74/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1396
# Epoch 00074: loss improved from 0.15316 to 0.13959, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 291s 5s/step - loss: 0.1396
# Epoch 75/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1360
# Epoch 00075: loss improved from 0.13959 to 0.13595, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 532s 10s/step - loss: 0.1360
# Epoch 76/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1361
# Epoch 00076: loss did not improve from 0.13595
# 55/55 [==============================] - 292s 5s/step - loss: 0.1361
# Epoch 77/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1286
# Epoch 00077: loss improved from 0.13595 to 0.12864, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 571s 10s/step - loss: 0.1286
# Epoch 78/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1196
# Epoch 00078: loss improved from 0.12864 to 0.11956, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 296s 5s/step - loss: 0.1196
# Epoch 79/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1343
# Epoch 00079: loss did not improve from 0.11956
# 55/55 [==============================] - 293s 5s/step - loss: 0.1343
# Epoch 80/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1135
# Epoch 00080: loss improved from 0.11956 to 0.11348, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 520s 9s/step - loss: 0.1135
# Epoch 81/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1134
# Epoch 00081: loss improved from 0.11348 to 0.11344, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 304s 6s/step - loss: 0.1134
# Epoch 82/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1111
# Epoch 00082: loss improved from 0.11344 to 0.11106, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 413s 8s/step - loss: 0.1111
# Epoch 83/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1067
# Epoch 00083: loss improved from 0.11106 to 0.10665, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 364s 7s/step - loss: 0.1067
# Epoch 84/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1022
# Epoch 00084: loss improved from 0.10665 to 0.10216, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 364s 7s/step - loss: 0.1022
# Epoch 85/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1002
# Epoch 00085: loss improved from 0.10216 to 0.10018, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 365s 7s/step - loss: 0.1002
# Epoch 86/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0948
# Epoch 00086: loss improved from 0.10018 to 0.09485, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 364s 7s/step - loss: 0.0948
# Epoch 87/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0926
# Epoch 00087: loss improved from 0.09485 to 0.09264, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 366s 7s/step - loss: 0.0926
# Epoch 88/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0921
# Epoch 00088: loss improved from 0.09264 to 0.09212, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 364s 7s/step - loss: 0.0921
# Epoch 89/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0893
# Epoch 00089: loss improved from 0.09212 to 0.08928, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 366s 7s/step - loss: 0.0893
# Epoch 90/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0830
# Epoch 00090: loss improved from 0.08928 to 0.08304, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 364s 7s/step - loss: 0.0830
# Epoch 91/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0876
# Epoch 00091: loss did not improve from 0.08304
# 55/55 [==============================] - 364s 7s/step - loss: 0.0876
# Epoch 92/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0831
# Epoch 00092: loss did not improve from 0.08304
# 55/55 [==============================] - 362s 7s/step - loss: 0.0831
# Epoch 93/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0807
# Epoch 00093: loss improved from 0.08304 to 0.08067, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 412s 7s/step - loss: 0.0807
# Epoch 94/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0840
# Epoch 00094: loss did not improve from 0.08067
# 55/55 [==============================] - 363s 7s/step - loss: 0.0840
# Epoch 95/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0868
# Epoch 00095: loss did not improve from 0.08067
# 55/55 [==============================] - 364s 7s/step - loss: 0.0868
# Epoch 96/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0779
# Epoch 00096: loss improved from 0.08067 to 0.07787, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 368s 7s/step - loss: 0.0779
# Epoch 97/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0762
# Epoch 00097: loss improved from 0.07787 to 0.07616, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 364s 7s/step - loss: 0.0762
# Epoch 98/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0734
# Epoch 00098: loss improved from 0.07616 to 0.07339, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 365s 7s/step - loss: 0.0734
# Epoch 99/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0726
# Epoch 00099: loss improved from 0.07339 to 0.07259, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 367s 7s/step - loss: 0.0726
# Epoch 100/100
# 55/55 [==============================] - ETA: 0s - loss: 0.0692
# Epoch 00100: loss improved from 0.07259 to 0.06921, saving model to model_weights_saved.hdf5
# 55/55 [==============================] - 425s 8s/step - loss: 0.0692

# %%
# recompile the model with the saved weights
filename = "model_weights_saved.hdf5"
model.load_weights(filename)
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam')

# %%
#output of the model
num_to_char = dict((i,c) for i,c in enumerate(chars))

# %%
# random seed to help gerenate
start = numpy.random.randint(0, len(x_data)-1)
pattern = x_data[start]
print("Random Seed:")
print("\"",' '.join([num_to_char[value] for value in pattern]),"\"")
# Out:
# Random Seed:
# " f o r m e d s u b j e c t e l e c t r i c i t y g a l v a n i s m n e w a s t o n i s h i n g s a i d t h r e w g r e a t l y s h a d e c o r n e l i u s a g r i p p a a l b e r t u s m a g n u s p a "

# %%
#generate the text
for i in range(2000):
    x = numpy.reshape(pattern, (1,len(pattern), 1))
    x = x/float(vocab_len)
    prediction = model.predict(x, verbose=0)
    index = numpy.argmax(prediction)
    result = num_to_char[index]
    seq_in = [num_to_char[value] for value in pattern]
    sys.stdout.write(result)
    pattern.append(index)
    pattern = pattern[1:len(pattern)]
# Out:
# ...
